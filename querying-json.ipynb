# %%
from collections.abc import MutableMapping
import json

# %%
class JsonHash:
    '''
    JsonHash is a Class enabling the processing and querying of JSON data.
    ROUGH example of how we could work with the hash table.
    '''
    def __init__(self, json_data, p_sparse=False):
        # store json
        # self.json_data = json_data
        # attribute to store the p_sparse parameter
        self.make_sparse = p_sparse
        # placeholder for query results
        self.results = []
        # hash the json object
        self.hash_table = self.hash_json(json_data)
        # reference for parsing the hash key
        # TODO: rename to json_map
        self.levels =   {
                        "member_id": 1,
                        "member_age": 1,
                        "member_sex": 1,
                        "claim": 1,
                        "claim_id": 3,
                        "claim_type": 3,   
                        "type_of_bill": 3,
                        "admission_date": 3,
                        "discharge_date": 3,
                        "taxonomy_code": 3,
                        "place_of_service": 3,
                        "principle_diagnosis": 3,
                        "diagnosis_codes": 3,
                        "drg": 3,  
                        "drg_severity": 3,
                        "drg_type": 3,
                        "claim_line": 3,
                        "line_number": 5,
                        "from_date": 5,
                        "thru_date": 5,
                        "revenue_code": 5,
                        "procedure_code": 5,
                        "ndc_code": 5,
                        "quantity": 5,
                        "allowed_amount": 5
                    }

    def hash_json(self, p_dictionary, p_parent_key=False, p_sparse=False):
        '''
        Gary's awesome JSON hashing function
        '''
        _items = []
        for _key, _value in p_dictionary.items():
            _new_key = str(p_parent_key) + '.' + _key if p_parent_key else _key
            if isinstance(_value, MutableMapping):
                # it's a dictionary
                if not _value.items():
                    # check for empty dictionary
                    _items.append((_new_key, None))
                else:
                    # not empty, recurse!
                    _items.extend(self.hash_json(_value, _new_key, self.make_sparse).items())
            elif isinstance(_value, list):
                # it's a list, so check to see if it's [not] empty
                if len(_value):
                    for _k, _v in enumerate(_value):
                        _items.extend(self.hash_json({str(_k): _v}, _new_key, self.make_sparse).items())
                else:
                    # empty list
                    _items.append((_new_key, None))
            else:
                # not dict or list, so append key, value
                if self.make_sparse is True and _value is None:
                        continue           
                _items.append((_new_key, _value))
        return dict(_items)

    def describe_json(self):
        '''
        OPTIONAL
        TODO: Pretty print the structure of the JSON object (json_map)
        '''
        return 

    def trimLastElement(self, key):
        '''
        Removes the last element from the hash key
        '''
        _new_key = key.split('.')[:-1]
        return '.'.join(_new_key)

    def mapStr(self, obj):
        '''
        Coerce list items to str
        '''
        return [i for i in map(str, obj)]

    def getLastElement(self, key): 
        '''
        Returns the last element of a key
        '''
        return key.split('.')[-1]


    def getKeyDepth(self, key):
        '''
        returns depth of a given key
        This is messy and highly specific to this work. We would need labels for the 
        various levels of the JSON to do this dynamically.
        '''
        _key = key.split('.')
        
        # if the last element is numeric, it's an array index, so go further back in the key
        # ex ['contents', '0', 'claim', '4', 'claim_line', '3', 'diagnosis_codes', '5']
        if _key[-1].isnumeric():
            return _key[-4]
        else:
            return _key[-3].replace('contents', 'member')

    def getMemberComponent(self, key):
        ''''
        Get member portion of key
        '''
        _key = key.split('.')
        try:
            return '.'.join(_key[:2])
        except IndexError:
            return None

    def getClaimComponent(self, key):
        ''''
        Get claim portion of key
        '''
        _key = key.split('.')
        try:
            return '.'.join(_key[:4])
        except IndexError:
            return None        

    def getClaimLineComponent(self, key):
        ''''
        Get claim line portion of key
        '''
        _key = key.split('.')
        try:
            return '.'.join(_key[:6])
        except IndexError:
            return None                        

    def getKeyInfo(self, key):
        '''
        key: a key from the hash table
        returns: a dictionary with information about the key of the form:
            {
                key: 'contents.0.claim.3.claim_line.3.procedure_code,
                depth: 'claim_line',
                member: 'contents.0',
                claim: 'contents.0.claim.3',
                claim_line: 'contents.0.claim.3.claim_line.3'
            }
        TODO: Once we have a schema generator, let's generalize this using the schema.
        '''
        _depth = self.getKeyDepth(key)
        return {
            'key': key,
            'depth': _depth,
            'member': self.getMemberComponent(key), # every key has a member component
            'claim': self.getClaimComponent(key) if _depth.startswith('claim') else None,
            'claim_line': self.getClaimLineComponent(key) if _depth == 'claim_line' else None
            }

    def find_or(self, search_values):
        '''
        values: dictionary of the form {data_element: [list of associated values]}
        Return a dictionary of the form: 
                {
                    data_element: [
                        {
                            key: 'contents.0.claim.5.claim_id',
                            depth: 'claim',
                            member: 'contents.0',
                            claim: 'contents.0.claim.5',
                            claim_line: None
                        }
                    ]
                }
        TODO: Can we chain this with another call to find?
                EX: find professional claims with 99214 and a specific taxonomy code
                    find(['P']).find(['99214']).find(['207QA0000X'])
        '''
        if not isinstance(search_values, dict):
            raise TypeError('Malformed parameter: search_values must be dict like object')
        
        # initialize dict with the keys = keys from the search_values dict
        _results_dict = {el: [] for el in search_values.keys()}
        
        # loop through the search criteria and build the _return_dict
        for _key, _values in search_values.items():
            # This sacrifices a lot of readability and may need to be refactored
            _results_dict.update({_key: [self.getKeyInfo(_k) for _k, _v in self.hash_table.items() if str(_v) in self.mapStr(_values) if self.getLastElement(_k)==_key]})

        return _results_dict

    def find_and(self, search_values):
        '''
        Find the intersection of keys in the results object
        Ex: 
        Matches the professional claim query:
            {'contents.0.claim.35.claim_type': 'P'}
        Matches the Office Visit query:
            {'contents.0.claim.35.claim_line.0.procedure_code': '99214'}
        Intersecting portion of the key is this claim for this member. It can be used
        to find the corresponding service date or provider taxonomy, etc.
            {'contents.0.claim.35}
        
        '''
        # obtain _results_dict from find_or method
        _results_dict = self.find_or(search_values)

        # initialize object to store all keys for matching
        _all_keys = {
            'member': [],
            'claim': [],
            'claim_line': []
        }

        # Example assuming 1 result per search criteria
        # Each item in the list is a set
        # 'member': []:
        # [{'contents.0'}, {'contents.0'}]

        # Pull out keys for each search criteria and store them as a set
        # in the object created above.
        # ex: 
        # { 'member': [set1, set2, set3], 
        #   'claim': [set1, set2, set3],
        #  ... }
        for key, values in _results_dict.items():
            _mbr_keys = []
            _clm_keys = []
            _clmln_keys = []
            for v in values:
                _mbr_keys.append(v['member'])
                _clm_keys.append(v['claim'])
                _clmln_keys.append(v['claim_line'])
            _all_keys['member'].append(set(_mbr_keys))
            _all_keys['claim'].append(set(_clm_keys))
            _all_keys['claim_line'].append(set(_clmln_keys))

        # Apply set intersection to identify keys that exist in all search results
        # first iteration: 
        #    all_keys['member'].pop().intersection(*_all_keys['member'])   
        for key in _all_keys.keys():
            _all_keys[key] = _all_keys[key].pop().intersection(*_all_keys[key])   

        return _all_keys

    def from_keys(self, values):
        '''
        values: list of values to search hash table for
        Return a subset of the hash table with the corresponding value
        TODO: Can we chain this with another call to from_values?
                EX: find professional claims with 99214 and a specific taxonomy code
                    find(['P']).find(['99214']).find(['207QA0000X'])
        '''
        self.results = self.find_or(values)
        return self

    def get_element(self, element):
        '''
        Return the desired data element; allows chaining with from_keys()
        This could accept a list.
        '''
        _results = []
        _ix = self.levels.get(element)
        _keys = set()
        for _key in self.results.keys():
            _parts = _key.split('.')[:_ix+1]
            # TODO: handle cases where we can't return the desired element
            _new_key = '.'.join(_parts + [element])
            # prevent duplicates in the output
            if _new_key not in _keys:
                _keys.add(_new_key)
                _results.append({_new_key: self.hash_table[_new_key]})
        return _results

# %%
with open('test_data/lambda_project_dummy_data.json', 'r') as f:
    members = json.load(f)

# %%
table = JsonHash(members, p_sparse=True)

# %%
table.hash_table
# Out:
# {'batch_id': 'dummy_data',
#  'sequence': 1,
#  'contents.0.member_id': 'mbr_01',
#  'contents.0.member_age': 348,
#  'contents.0.member_sex': 'F',
#  'contents.0.claim.0.claim_id': 'clm_0101',
#  'contents.0.claim.0.claim_type': 'P',
#  'contents.0.claim.0.admission_date': '2019-02-12',
#  'contents.0.claim.0.discharge_date': '2019-02-12',
#  'contents.0.claim.0.taxonomy_code': '363A00000X',
#  'contents.0.claim.0.place_of_service': 11,
#  'contents.0.claim.0.principle_diagnosis': 'F909',
#  'contents.0.claim.0.diagnosis_codes.0': 'F909',
#  'contents.0.claim.0.claim_line.0.line_number': 1,
#  'contents.0.claim.0.claim_line.0.from_date': '2019-02-12',
#  'contents.0.claim.0.claim_line.0.thru_date': '2019-02-12',
#  'contents.0.claim.0.claim_line.0.procedure_code': '99215',
#  'contents.0.claim.0.claim_line.0.quantity': 1,
#  'contents.0.claim.0.claim_line.0.allowed_amount': 174.25,
#  'contents.0.claim.0.claim_line.1.line_number': 2,
#  'contents.0.claim.0.claim_line.1.from_date': '2019-02-12',
#  'contents.0.claim.0.claim_line.1.thru_date': '2019-02-12',
#  'contents.0.claim.0.claim_line.1.procedure_code': '96127',
#  'contents.0.claim.0.claim_line.1.quantity': 2,
#  'contents.0.claim.0.claim_line.1.allowed_amount': 0,
#  'contents.0.claim.0.claim_line.2.line_number': 3,
#  'contents.0.claim.0.claim_line.2.from_date': '2019-02-12',
#  'contents.0.claim.0.claim_line.2.thru_date': '2019-02-12',
#  'contents.0.claim.0.claim_line.2.procedure_code': '96138',
#  'contents.0.claim.0.claim_line.2.quantity': 1,
#  'contents.0.claim.0.claim_line.2.allowed_amount': 45.9,
#  'contents.0.claim.1.claim_id': 'clm_0102',
#  'contents.0.claim.1.claim_type': 'R',
#  'contents.0.claim.1.admission_date': '2019-04-09',
#  'contents.0.claim.1.discharge_date': '2019-04-09',
#  'contents.0.claim.1.claim_line.0.line_number': 1,
#  'contents.0.claim.1.claim_line.0.from_date': '2019-04-09',
#  'contents.0.claim.1.claim_line.0.thru_date': '2019-04-09',
#  'contents.0.claim.1.claim_line.0.ndc_code': '68462013281',
#  'contents.0.claim.1.claim_line.0.quantity': 63,
#  'contents.0.claim.1.claim_line.0.allowed_amount': 33,
#  'contents.0.claim.2.claim_id': 'clm_0103',
#  'contents.0.claim.2.claim_type': 'R',
#  'contents.0.claim.2.admission_date': '2019-03-06',
#  'contents.0.claim.2.discharge_date': '2019-03-06',
#  'contents.0.claim.2.claim_line.0.line_number': 1,
#  'contents.0.claim.2.claim_line.0.from_date': '2019-03-06',
#  'contents.0.claim.2.claim_line.0.thru_date': '2019-03-06',
#  'contents.0.claim.2.claim_line.0.ndc_code': '69238183801',
#  'contents.0.claim.2.claim_line.0.quantity': 90,
#  'contents.0.claim.2.claim_line.0.allowed_amount': 30.19,
#  'contents.0.claim.3.claim_id': 'clm_0104',
#  'contents.0.claim.3.claim_type': 'P',
#  'contents.0.claim.3.admission_date': '2019-04-02',
#  'contents.0.claim.3.discharge_date': '2019-04-02',
#  'contents.0.claim.3.taxonomy_code': '225100000X',
#  'contents.0.claim.3.place_of_service': 11,
#  'contents.0.claim.3.principle_diagnosis': 'M79645',
#  'contents.0.claim.3.diagnosis_codes.0': 'M79645',
#  'contents.0.claim.3.claim_line.0.line_number': 1,
#  'contents.0.claim.3.claim_line.0.from_date': '2019-04-02',
#  'contents.0.claim.3.claim_line.0.thru_date': '2019-04-02',
#  'contents.0.claim.3.claim_line.0.procedure_code': '97161',
#  'contents.0.claim.3.claim_line.0.quantity': 1,
#  'contents.0.claim.3.claim_line.0.allowed_amount': 82.11,
#  'contents.0.claim.3.claim_line.1.line_number': 2,
#  'contents.0.claim.3.claim_line.1.from_date': '2019-04-02',
#  'contents.0.claim.3.claim_line.1.thru_date': '2019-04-02',
#  'contents.0.claim.3.claim_line.1.procedure_code': '97530',
#  'contents.0.claim.3.claim_line.1.quantity': 1,
#  'contents.0.claim.3.claim_line.1.allowed_amount': 39.68,
#  'contents.0.claim.3.claim_line.2.line_number': 3,
#  'contents.0.claim.3.claim_line.2.from_date': '2019-04-02',
#  'contents.0.claim.3.claim_line.2.thru_date': '2019-04-02',
#  'contents.0.claim.3.claim_line.2.procedure_code': 'L3913',
#  'contents.0.claim.3.claim_line.2.quantity': 1,
#  'contents.0.claim.3.claim_line.2.allowed_amount': 203.04,
#  'contents.0.claim.4.claim_id': 'clm_0105',
#  'contents.0.claim.4.claim_type': 'R',
#  'contents.0.claim.4.admission_date': '2018-10-05',
#  'contents.0.claim.4.discharge_date': '2018-10-05',
#  'contents.0.claim.4.claim_line.0.line_number': 1,
#  'contents.0.claim.4.claim_line.0.from_date': '2018-10-05',
#  'contents.0.claim.4.claim_line.0.thru_date': '2018-10-05',
#  'contents.0.claim.4.claim_line.0.ndc_code': '00527134901',
#  'contents.0.claim.4.claim_line.0.quantity': 90,
#  'contents.0.claim.4.claim_line.0.allowed_amount': 42.71,
#  'contents.0.claim.5.claim_id': 'clm_0106',
#  'contents.0.claim.5.claim_type': 'R',
#  'contents.0.claim.5.admission_date': '2018-12-08',
#  'contents.0.claim.5.discharge_date': '2018-12-08',
#  'contents.0.claim.5.claim_line.0.line_number': 1,
#  'contents.0.claim.5.claim_line.0.from_date': '2018-12-08',
#  'contents.0.claim.5.claim_line.0.thru_date': '2018-12-08',
#  'contents.0.claim.5.claim_line.0.ndc_code': '10702010001',
#  'contents.0.claim.5.claim_line.0.quantity': 60,
#  'contents.0.claim.5.claim_line.0.allowed_amount': 21.01,
#  'contents.0.claim.6.claim_id': 'clm_0107',
#  'contents.0.claim.6.claim_type': 'P',
#  'contents.0.claim.6.admission_date': '2019-04-23',
#  'contents.0.claim.6.discharge_date': '2019-04-23',
#  'contents.0.claim.6.taxonomy_code': '101YM0800X',
#  'contents.0.claim.6.place_of_service': 11,
#  'contents.0.claim.6.principle_diagnosis': 'F909',
#  'contents.0.claim.6.diagnosis_codes.0': 'F909',
#  'contents.0.claim.6.claim_line.0.line_number': 1,
#  'contents.0.claim.6.claim_line.0.from_date': '2019-04-23',
#  'contents.0.claim.6.claim_line.0.thru_date': '2019-04-23',
#  'contents.0.claim.6.claim_line.0.procedure_code': '90837',
#  'contents.0.claim.6.claim_line.0.quantity': 1,
#  'contents.0.claim.6.claim_line.0.allowed_amount': 91.15,
#  'contents.0.claim.6.claim_line.1.line_number': 2,
#  'contents.0.claim.6.claim_line.1.from_date': '2019-04-23',
#  'contents.0.claim.6.claim_line.1.thru_date': '2019-04-23',
#  'contents.0.claim.6.claim_line.1.procedure_code': '96127',
#  'contents.0.claim.6.claim_line.1.quantity': 2,
#  'contents.0.claim.6.claim_line.1.allowed_amount': 0,
#  'contents.0.claim.7.claim_id': 'clm_0108',
#  'contents.0.claim.7.claim_type': 'P',
#  'contents.0.claim.7.admission_date': '2019-01-08',
#  'contents.0.claim.7.discharge_date': '2019-01-08',
#  'contents.0.claim.7.taxonomy_code': '363A00000X',
#  'contents.0.claim.7.place_of_service': 11,
#  'contents.0.claim.7.principle_diagnosis': 'F909',
#  'contents.0.claim.7.diagnosis_codes.0': 'F909',
#  'contents.0.claim.7.claim_line.0.line_number': 1,
#  'contents.0.claim.7.claim_line.0.from_date': '2019-01-08',
#  'contents.0.claim.7.claim_line.0.thru_date': '2019-01-08',
#  'contents.0.claim.7.claim_line.0.procedure_code': '99214',
#  'contents.0.claim.7.claim_line.0.quantity': 1,
#  'contents.0.claim.7.claim_line.0.allowed_amount': 129.2,
#  'contents.0.claim.7.claim_line.1.line_number': 2,
#  'contents.0.claim.7.claim_line.1.from_date': '2019-01-08',
#  'contents.0.claim.7.claim_line.1.thru_date': '2019-01-08',
#  'contents.0.claim.7.claim_line.1.procedure_code': '96127',
#  'contents.0.claim.7.claim_line.1.quantity': 2,
#  'contents.0.claim.7.claim_line.1.allowed_amount': 15.3,
#  'contents.0.claim.8.claim_id': 'clm_0109',
#  'contents.0.claim.8.claim_type': 'R',
#  'contents.0.claim.8.admission_date': '2019-04-02',
#  'contents.0.claim.8.discharge_date': '2019-04-02',
#  'contents.0.claim.8.claim_line.0.line_number': 1,
#  'contents.0.claim.8.claim_line.0.from_date': '2019-04-02',
#  'contents.0.claim.8.claim_line.0.thru_date': '2019-04-02',
#  'contents.0.claim.8.claim_line.0.ndc_code': '10702010001',
#  'contents.0.claim.8.claim_line.0.quantity': 60,
#  'contents.0.claim.8.claim_line.0.allowed_amount': 17.21,
#  'contents.0.claim.9.claim_id': 'clm_0110',
#  'contents.0.claim.9.claim_type': 'P',
#  'contents.0.claim.9.admission_date': '2019-03-12',
#  'contents.0.claim.9.discharge_date': '2019-03-12',
#  'contents.0.claim.9.taxonomy_code': '101YM0800X',
#  'contents.0.claim.9.place_of_service': 11,
#  'contents.0.claim.9.principle_diagnosis': 'F909',
#  'contents.0.claim.9.diagnosis_codes.0': 'F909',
#  'contents.0.claim.9.claim_line.0.line_number': 1,
#  'contents.0.claim.9.claim_line.0.from_date': '2019-03-12',
#  'contents.0.claim.9.claim_line.0.thru_date': '2019-03-12',
#  'contents.0.claim.9.claim_line.0.procedure_code': '90837',
#  'contents.0.claim.9.claim_line.0.quantity': 1,
#  'contents.0.claim.9.claim_line.0.allowed_amount': 91.15,
#  'contents.0.claim.9.claim_line.1.line_number': 2,
#  'contents.0.claim.9.claim_line.1.from_date': '2019-03-12',
#  'contents.0.claim.9.claim_line.1.thru_date': '2019-03-12',
#  'contents.0.claim.9.claim_line.1.procedure_code': '96127',
#  'contents.0.claim.9.claim_line.1.quantity': 2,
#  'contents.0.claim.9.claim_line.1.allowed_amount': 0,
#  'contents.0.claim.10.claim_id': 'clm_0111',
#  'contents.0.claim.10.claim_type': 'P',
#  'contents.0.claim.10.admission_date': '2018-12-04',
#  'contents.0.claim.10.discharge_date': '2018-12-04',
#  'contents.0.claim.10.taxonomy_code': '225100000X',
#  'contents.0.claim.10.place_of_service': 11,
#  'contents.0.claim.10.principle_diagnosis': 'M25551',
#  'contents.0.claim.10.diagnosis_codes.0': 'M25551',
#  'contents.0.claim.10.claim_line.0.line_number': 1,
#  'contents.0.claim.10.claim_line.0.from_date': '2018-12-04',
#  'contents.0.claim.10.claim_line.0.thru_date': '2018-12-04',
#  'contents.0.claim.10.claim_line.0.procedure_code': '97161',
#  'contents.0.claim.10.claim_line.0.quantity': 1,
#  'contents.0.claim.10.claim_line.0.allowed_amount': 78.66,
#  'contents.0.claim.10.claim_line.1.line_number': 2,
#  'contents.0.claim.10.claim_line.1.from_date': '2018-12-04',
#  'contents.0.claim.10.claim_line.1.thru_date': '2018-12-04',
#  'contents.0.claim.10.claim_line.1.procedure_code': '97530',
#  'contents.0.claim.10.claim_line.1.quantity': 1,
#  'contents.0.claim.10.claim_line.1.allowed_amount': 33.81,
#  'contents.0.claim.11.claim_id': 'clm_0112',
#  'contents.0.claim.11.claim_type': 'P',
#  'contents.0.claim.11.admission_date': '2019-05-08',
#  'contents.0.claim.11.discharge_date': '2019-05-08',
#  'contents.0.claim.11.taxonomy_code': '207Q00000X',
#  'contents.0.claim.11.place_of_service': 11,
#  'contents.0.claim.11.principle_diagnosis': 'M25551',
#  'contents.0.claim.11.diagnosis_codes.0': 'M25551',
#  'contents.0.claim.11.diagnosis_codes.1': 'Z8639',
#  'contents.0.claim.11.diagnosis_codes.2': 'M7061',
#  'contents.0.claim.11.diagnosis_codes.3': 'G5701',
#  'contents.0.claim.11.claim_line.0.line_number': 1,
#  'contents.0.claim.11.claim_line.0.from_date': '2019-05-08',
#  'contents.0.claim.11.claim_line.0.thru_date': '2019-05-08',
#  'contents.0.claim.11.claim_line.0.procedure_code': '99213',
#  'contents.0.claim.11.claim_line.0.quantity': 1,
#  'contents.0.claim.11.claim_line.0.allowed_amount': 162.87,
#  'contents.0.claim.12.claim_id': 'clm_0113',
#  'contents.0.claim.12.claim_type': 'R',
#  'contents.0.claim.12.admission_date': '2019-06-04',
#  'contents.0.claim.12.discharge_date': '2019-06-04',
#  'contents.0.claim.12.claim_line.0.line_number': 1,
#  'contents.0.claim.12.claim_line.0.from_date': '2019-06-04',
#  'contents.0.claim.12.claim_line.0.thru_date': '2019-06-04',
#  'contents.0.claim.12.claim_line.0.ndc_code': '65862001205',
#  'contents.0.claim.12.claim_line.0.quantity': 90,
#  'contents.0.claim.12.claim_line.0.allowed_amount': 7.18,
#  'contents.0.claim.13.claim_id': 'clm_0114',
#  'contents.0.claim.13.claim_type': 'R',
#  'contents.0.claim.13.admission_date': '2019-05-07',
#  'contents.0.claim.13.discharge_date': '2019-05-07',
#  'contents.0.claim.13.claim_line.0.line_number': 1,
#  'contents.0.claim.13.claim_line.0.from_date': '2019-05-07',
#  'contents.0.claim.13.claim_line.0.thru_date': '2019-05-07',
#  'contents.0.claim.13.claim_line.0.ndc_code': '10702010101',
#  'contents.0.claim.13.claim_line.0.quantity': 60,
#  'contents.0.claim.13.claim_line.0.allowed_amount': 23.94,
#  'contents.0.claim.14.claim_id': 'clm_0115',
#  'contents.0.claim.14.claim_type': 'P',
#  'contents.0.claim.14.admission_date': '2018-12-22',
#  'contents.0.claim.14.discharge_date': '2018-12-22',
#  'contents.0.claim.14.taxonomy_code': '363A00000X',
#  'contents.0.claim.14.place_of_service': 11,
#  'contents.0.claim.14.principle_diagnosis': 'H00025',
#  'contents.0.claim.14.diagnosis_codes.0': 'H00025',
#  'contents.0.claim.14.claim_line.0.line_number': 1,
#  'contents.0.claim.14.claim_line.0.from_date': '2018-12-22',
#  'contents.0.claim.14.claim_line.0.thru_date': '2018-12-22',
#  'contents.0.claim.14.claim_line.0.procedure_code': '99202',
#  'contents.0.claim.14.claim_line.0.quantity': 1,
#  'contents.0.claim.14.claim_line.0.allowed_amount': 122.55,
#  'contents.0.claim.15.claim_id': 'clm_0116',
#  'contents.0.claim.15.claim_type': 'P',
#  'contents.0.claim.15.admission_date': '2018-12-06',
#  'contents.0.claim.15.discharge_date': '2018-12-06',
#  'contents.0.claim.15.taxonomy_code': '225100000X',
#  'contents.0.claim.15.place_of_service': 11,
#  'contents.0.claim.15.principle_diagnosis': 'M25551',
#  'contents.0.claim.15.diagnosis_codes.0': 'M25551',
#  'contents.0.claim.15.claim_line.0.line_number': 1,
#  'contents.0.claim.15.claim_line.0.from_date': '2018-12-06',
#  'contents.0.claim.15.claim_line.0.thru_date': '2018-12-06',
#  'contents.0.claim.15.claim_line.0.procedure_code': '97110',
#  'contents.0.claim.15.claim_line.0.quantity': 2,
#  'contents.0.claim.15.claim_line.0.allowed_amount': 62.8,
#  'contents.0.claim.16.claim_id': 'clm_0117',
#  'contents.0.claim.16.claim_type': 'R',
#  'contents.0.claim.16.admission_date': '2018-06-01',
#  'contents.0.claim.16.discharge_date': '2018-06-01',
#  'contents.0.claim.16.claim_line.0.line_number': 1,
#  'contents.0.claim.16.claim_line.0.from_date': '2018-06-01',
#  'contents.0.claim.16.claim_line.0.thru_date': '2018-06-01',
#  'contents.0.claim.16.claim_line.0.ndc_code': '00527134901',
#  'contents.0.claim.16.claim_line.0.quantity': 90,
#  'contents.0.claim.16.claim_line.0.allowed_amount': 41.03,
#  'contents.0.claim.17.claim_id': 'clm_0118',
#  'contents.0.claim.17.claim_type': 'R',
#  'contents.0.claim.17.admission_date': '2018-06-01',
#  'contents.0.claim.17.discharge_date': '2018-06-01',
#  'contents.0.claim.17.claim_line.0.line_number': 1,
#  'contents.0.claim.17.claim_line.0.from_date': '2018-06-01',
#  'contents.0.claim.17.claim_line.0.thru_date': '2018-06-01',
#  'contents.0.claim.17.claim_line.0.ndc_code': '65862001205',
#  'contents.0.claim.17.claim_line.0.quantity': 90,
#  'contents.0.claim.17.claim_line.0.allowed_amount': 6.96,
#  'contents.0.claim.18.claim_id': 'clm_0119',
#  'contents.0.claim.18.claim_type': 'P',
#  'contents.0.claim.18.admission_date': '2019-03-26',
#  'contents.0.claim.18.discharge_date': '2019-03-26',
#  'contents.0.claim.18.taxonomy_code': '101YM0800X',
#  'contents.0.claim.18.place_of_service': 11,
#  'contents.0.claim.18.principle_diagnosis': 'F909',
#  'contents.0.claim.18.diagnosis_codes.0': 'F909',
#  'contents.0.claim.18.claim_line.0.line_number': 1,
#  'contents.0.claim.18.claim_line.0.from_date': '2019-03-26',
#  'contents.0.claim.18.claim_line.0.thru_date': '2019-03-26',
#  'contents.0.claim.18.claim_line.0.procedure_code': '90837',
#  'contents.0.claim.18.claim_line.0.quantity': 1,
#  'contents.0.claim.18.claim_line.0.allowed_amount': 91.15,
#  'contents.0.claim.18.claim_line.1.line_number': 2,
#  'contents.0.claim.18.claim_line.1.from_date': '2019-03-26',
#  'contents.0.claim.18.claim_line.1.thru_date': '2019-03-26',
#  'contents.0.claim.18.claim_line.1.procedure_code': '96127',
#  'contents.0.claim.18.claim_line.1.quantity': 1,
#  'contents.0.claim.18.claim_line.1.allowed_amount': 0,
#  'contents.0.claim.19.claim_id': 'clm_0120',
#  'contents.0.claim.19.claim_type': 'P',
#  'contents.0.claim.19.admission_date': '2019-04-09',
#  'contents.0.claim.19.discharge_date': '2019-04-09',
#  'contents.0.claim.19.taxonomy_code': '207Q00000X',
#  'contents.0.claim.19.place_of_service': 11,
#  'contents.0.claim.19.principle_diagnosis': 'Z0000',
#  'contents.0.claim.19.diagnosis_codes.0': 'Z0000',
#  'contents.0.claim.19.diagnosis_codes.1': 'Z8639',
#  'contents.0.claim.19.diagnosis_codes.2': 'E6609',
#  'contents.0.claim.19.diagnosis_codes.3': 'Z6835',
#  'contents.0.claim.19.claim_line.0.line_number': 1,
#  'contents.0.claim.19.claim_line.0.from_date': '2019-04-09',
#  'contents.0.claim.19.claim_line.0.thru_date': '2019-04-09',
#  'contents.0.claim.19.claim_line.0.procedure_code': '83970',
#  'contents.0.claim.19.claim_line.0.quantity': 1,
#  'contents.0.claim.19.claim_line.0.allowed_amount': 54.57,
#  'contents.0.claim.19.claim_line.1.line_number': 2,
#  'contents.0.claim.19.claim_line.1.from_date': '2019-04-09',
#  'contents.0.claim.19.claim_line.1.thru_date': '2019-04-09',
#  'contents.0.claim.19.claim_line.1.procedure_code': '82310',
#  'contents.0.claim.19.claim_line.1.quantity': 1,
#  'contents.0.claim.19.claim_line.1.allowed_amount': 6.82,
#  'contents.0.claim.19.claim_line.2.line_number': 3,
#  'contents.0.claim.19.claim_line.2.from_date': '2019-04-09',
#  'contents.0.claim.19.claim_line.2.thru_date': '2019-04-09',
#  'contents.0.claim.19.claim_line.2.procedure_code': '80061',
#  'contents.0.claim.19.claim_line.2.quantity': 1,
#  'contents.0.claim.19.claim_line.2.allowed_amount': 17.71,
#  'contents.0.claim.19.claim_line.3.line_number': 4,
#  'contents.0.claim.19.claim_line.3.from_date': '2019-04-09',
#  'contents.0.claim.19.claim_line.3.thru_date': '2019-04-09',
#  'contents.0.claim.19.claim_line.3.procedure_code': '82306',
#  'contents.0.claim.19.claim_line.3.quantity': 1,
#  'contents.0.claim.19.claim_line.3.allowed_amount': 0,
#  'contents.0.claim.19.claim_line.4.line_number': 5,
#  'contents.0.claim.19.claim_line.4.from_date': '2019-04-09',
#  'contents.0.claim.19.claim_line.4.thru_date': '2019-04-09',
#  'contents.0.claim.19.claim_line.4.procedure_code': '82607',
#  'contents.0.claim.19.claim_line.4.quantity': 1,
#  'contents.0.claim.19.claim_line.4.allowed_amount': 19.93,
#  'contents.0.claim.19.claim_line.5.line_number': 6,
#  'contents.0.claim.19.claim_line.5.from_date': '2019-04-09',
#  'contents.0.claim.19.claim_line.5.thru_date': '2019-04-09',
#  'contents.0.claim.19.claim_line.5.procedure_code': '36415',
#  'contents.0.claim.19.claim_line.5.quantity': 1,
#  'contents.0.claim.19.claim_line.5.allowed_amount': 3.57,
#  'contents.0.claim.20.claim_id': 'clm_0121',
#  'contents.0.claim.20.claim_type': 'R',
#  'contents.0.claim.20.admission_date': '2019-01-12',
#  'contents.0.claim.20.discharge_date': '2019-01-12',
#  'contents.0.claim.20.claim_line.0.line_number': 1,
#  'contents.0.claim.20.claim_line.0.from_date': '2019-01-12',
#  'contents.0.claim.20.claim_line.0.thru_date': '2019-01-12',
#  'contents.0.claim.20.claim_line.0.ndc_code': '10702010001',
#  'contents.0.claim.20.claim_line.0.quantity': 60,
#  'contents.0.claim.20.claim_line.0.allowed_amount': 17.26,
#  'contents.0.claim.21.claim_id': 'clm_0122',
#  'contents.0.claim.21.claim_type': 'R',
#  'contents.0.claim.21.admission_date': '2019-06-17',
#  'contents.0.claim.21.discharge_date': '2019-06-17',
#  'contents.0.claim.21.claim_line.0.line_number': 1,
#  'contents.0.claim.21.claim_line.0.from_date': '2019-06-17',
#  'contents.0.claim.21.claim_line.0.thru_date': '2019-06-17',
#  'contents.0.claim.21.claim_line.0.ndc_code': '00406114401',
#  'contents.0.claim.21.claim_line.0.quantity': 180,
#  'contents.0.claim.21.claim_line.0.allowed_amount': 69.86,
#  'contents.0.claim.22.claim_id': 'clm_0123',
#  'contents.0.claim.22.claim_type': 'P',
#  'contents.0.claim.22.admission_date': '2019-05-14',
#  'contents.0.claim.22.discharge_date': '2019-05-14',
#  'contents.0.claim.22.taxonomy_code': '101YM0800X',
#  'contents.0.claim.22.place_of_service': 11,
#  'contents.0.claim.22.principle_diagnosis': 'F909',
#  'contents.0.claim.22.diagnosis_codes.0': 'F909',
#  'contents.0.claim.22.claim_line.0.line_number': 1,
#  'contents.0.claim.22.claim_line.0.from_date': '2019-05-14',
#  'contents.0.claim.22.claim_line.0.thru_date': '2019-05-14',
#  'contents.0.claim.22.claim_line.0.procedure_code': '90837',
#  'contents.0.claim.22.claim_line.0.quantity': 1,
#  'contents.0.claim.22.claim_line.0.allowed_amount': 91.15,
#  'contents.0.claim.22.claim_line.1.line_number': 2,
#  'contents.0.claim.22.claim_line.1.from_date': '2019-05-14',
#  'contents.0.claim.22.claim_line.1.thru_date': '2019-05-14',
#  'contents.0.claim.22.claim_line.1.procedure_code': '96127',
#  'contents.0.claim.22.claim_line.1.quantity': 2,
#  'contents.0.claim.22.claim_line.1.allowed_amount': 0,
#  'contents.0.claim.23.claim_id': 'clm_0124',
#  'contents.0.claim.23.claim_type': 'P',
#  'contents.0.claim.23.admission_date': '2019-03-05',
#  'contents.0.claim.23.discharge_date': '2019-03-05',
#  'contents.0.claim.23.taxonomy_code': '101YM0800X',
#  'contents.0.claim.23.place_of_service': 11,
#  'contents.0.claim.23.principle_diagnosis': 'F909',
#  'contents.0.claim.23.diagnosis_codes.0': 'F909',
#  'contents.0.claim.23.claim_line.0.line_number': 1,
#  'contents.0.claim.23.claim_line.0.from_date': '2019-03-05',
#  'contents.0.claim.23.claim_line.0.thru_date': '2019-03-05',
#  'contents.0.claim.23.claim_line.0.procedure_code': '90837',
#  'contents.0.claim.23.claim_line.0.quantity': 1,
#  'contents.0.claim.23.claim_line.0.allowed_amount': 91.15,
#  'contents.0.claim.23.claim_line.1.line_number': 2,
#  'contents.0.claim.23.claim_line.1.from_date': '2019-03-05',
#  'contents.0.claim.23.claim_line.1.thru_date': '2019-03-05',
#  'contents.0.claim.23.claim_line.1.procedure_code': '96127',
#  'contents.0.claim.23.claim_line.1.quantity': 2,
#  'contents.0.claim.23.claim_line.1.allowed_amount': 0,
#  'contents.0.claim.24.claim_id': 'clm_0125',
#  'contents.0.claim.24.claim_type': 'R',
#  'contents.0.claim.24.admission_date': '2019-05-13',
#  'contents.0.claim.24.discharge_date': '2019-05-13',
#  'contents.0.claim.24.claim_line.0.line_number': 1,
#  'contents.0.claim.24.claim_line.0.from_date': '2019-05-13',
#  'contents.0.claim.24.claim_line.0.thru_date': '2019-05-13',
#  'contents.0.claim.24.claim_line.0.ndc_code': '00591271701',
#  'contents.0.claim.24.claim_line.0.quantity': 30,
#  'contents.0.claim.24.claim_line.0.allowed_amount': 216.71,
#  'contents.0.claim.25.claim_id': 'clm_0126',
#  'contents.0.claim.25.claim_type': 'P',
#  'contents.0.claim.25.admission_date': '2019-03-19',
#  'contents.0.claim.25.discharge_date': '2019-03-19',
#  'contents.0.claim.25.taxonomy_code': '101YM0800X',
#  'contents.0.claim.25.place_of_service': 11,
#  'contents.0.claim.25.principle_diagnosis': 'F909',
#  'contents.0.claim.25.diagnosis_codes.0': 'F909',
#  'contents.0.claim.25.claim_line.0.line_number': 1,
#  'contents.0.claim.25.claim_line.0.from_date': '2019-03-19',
#  'contents.0.claim.25.claim_line.0.thru_date': '2019-03-19',
#  'contents.0.claim.25.claim_line.0.procedure_code': '90837',
#  'contents.0.claim.25.claim_line.0.quantity': 1,
#  'contents.0.claim.25.claim_line.0.allowed_amount': 91.15,
#  'contents.0.claim.25.claim_line.1.line_number': 2,
#  'contents.0.claim.25.claim_line.1.from_date': '2019-03-19',
#  'contents.0.claim.25.claim_line.1.thru_date': '2019-03-19',
#  'contents.0.claim.25.claim_line.1.procedure_code': '96127',
#  'contents.0.claim.25.claim_line.1.quantity': 2,
#  'contents.0.claim.25.claim_line.1.allowed_amount': 0,
#  'contents.0.claim.26.claim_id': 'clm_0127',
#  'contents.0.claim.26.claim_type': 'P',
#  'contents.0.claim.26.admission_date': '2019-06-10',
#  'contents.0.claim.26.discharge_date': '2019-06-10',
#  'contents.0.claim.26.taxonomy_code': '225100000X',
#  'contents.0.claim.26.place_of_service': 11,
#  'contents.0.claim.26.principle_diagnosis': 'M25551',
#  'contents.0.claim.26.diagnosis_codes.0': 'M25551',
#  'contents.0.claim.26.diagnosis_codes.1': 'N393',
#  'contents.0.claim.26.claim_line.0.line_number': 1,
#  'contents.0.claim.26.claim_line.0.from_date': '2019-06-10',
#  'contents.0.claim.26.claim_line.0.thru_date': '2019-06-10',
#  'contents.0.claim.26.claim_line.0.procedure_code': '97530',
#  'contents.0.claim.26.claim_line.0.quantity': 4,
#  'contents.0.claim.26.claim_line.0.allowed_amount': 158.72,
#  'contents.0.claim.27.claim_id': 'clm_0128',
#  'contents.0.claim.27.claim_type': 'P',
#  'contents.0.claim.27.admission_date': '2019-05-23',
#  'contents.0.claim.27.discharge_date': '2019-05-23',
#  'contents.0.claim.27.taxonomy_code': '101YM0800X',
#  'contents.0.claim.27.place_of_service': 11,
#  'contents.0.claim.27.principle_diagnosis': 'F909',
#  'contents.0.claim.27.diagnosis_codes.0': 'F909',
#  'contents.0.claim.27.claim_line.0.line_number': 1,
#  'contents.0.claim.27.claim_line.0.from_date': '2019-05-23',
#  'contents.0.claim.27.claim_line.0.thru_date': '2019-05-23',
#  'contents.0.claim.27.claim_line.0.procedure_code': '90837',
#  'contents.0.claim.27.claim_line.0.quantity': 1,
#  'contents.0.claim.27.claim_line.0.allowed_amount': 91.15,
#  'contents.0.claim.27.claim_line.1.line_number': 2,
#  'contents.0.claim.27.claim_line.1.from_date': '2019-05-23',
#  'contents.0.claim.27.claim_line.1.thru_date': '2019-05-23',
#  'contents.0.claim.27.claim_line.1.procedure_code': '96127',
#  'contents.0.claim.27.claim_line.1.quantity': 2,
#  'contents.0.claim.27.claim_line.1.allowed_amount': 0,
#  'contents.0.claim.28.claim_id': 'clm_0129',
#  'contents.0.claim.28.claim_type': 'R',
#  'contents.0.claim.28.admission_date': '2019-06-17',
#  'contents.0.claim.28.discharge_date': '2019-06-17',
#  'contents.0.claim.28.claim_line.0.line_number': 1,
#  'contents.0.claim.28.claim_line.0.from_date': '2019-06-17',
#  'contents.0.claim.28.claim_line.0.thru_date': '2019-06-17',
#  'contents.0.claim.28.claim_line.0.ndc_code': '62037072601',
#  'contents.0.claim.28.claim_line.0.quantity': 90,
#  'contents.0.claim.28.claim_line.0.allowed_amount': 648.18,
#  'contents.0.claim.29.claim_id': 'clm_0130',
#  'contents.0.claim.29.claim_type': 'R',
#  'contents.0.claim.29.admission_date': '2019-04-12',
#  'contents.0.claim.29.discharge_date': '2019-04-12',
#  'contents.0.claim.29.claim_line.0.line_number': 1,
#  'contents.0.claim.29.claim_line.0.from_date': '2019-04-12',
#  'contents.0.claim.29.claim_line.0.thru_date': '2019-04-12',
#  'contents.0.claim.29.claim_line.0.ndc_code': '00591271701',
#  'contents.0.claim.29.claim_line.0.quantity': 30,
#  'contents.0.claim.29.claim_line.0.allowed_amount': 216.71,
#  'contents.0.claim.30.claim_id': 'clm_0131',
#  'contents.0.claim.30.claim_type': 'P',
#  'contents.0.claim.30.admission_date': '2018-03-01',
#  'contents.0.claim.30.discharge_date': '2018-03-01',
#  'contents.0.claim.30.taxonomy_code': '2085R0202X',
#  'contents.0.claim.30.place_of_service': 11,
#  'contents.0.claim.30.principle_diagnosis': 'M25551',
#  'contents.0.claim.30.diagnosis_codes.0': 'M25551',
#  'contents.0.claim.30.claim_line.0.line_number': 1,
#  'contents.0.claim.30.claim_line.0.from_date': '2018-03-01',
#  'contents.0.claim.30.claim_line.0.thru_date': '2018-03-01',
#  'contents.0.claim.30.claim_line.0.procedure_code': '73502',
#  'contents.0.claim.30.claim_line.0.quantity': 1,
#  'contents.0.claim.30.claim_line.0.allowed_amount': 88.72,
#  'contents.0.claim.31.claim_id': 'clm_0132',
#  'contents.0.claim.31.claim_type': 'R',
#  'contents.0.claim.31.admission_date': '2019-01-12',
#  'contents.0.claim.31.discharge_date': '2019-01-12',
#  'contents.0.claim.31.claim_line.0.line_number': 1,
#  'contents.0.claim.31.claim_line.0.from_date': '2019-01-12',
#  'contents.0.claim.31.claim_line.0.thru_date': '2019-01-12',
#  'contents.0.claim.31.claim_line.0.ndc_code': '00591271701',
#  'contents.0.claim.31.claim_line.0.quantity': 30,
#  'contents.0.claim.31.claim_line.0.allowed_amount': 216.76,
#  'contents.0.claim.32.claim_id': 'clm_0133',
#  'contents.0.claim.32.claim_type': 'R',
#  'contents.0.claim.32.admission_date': '2019-06-05',
#  'contents.0.claim.32.discharge_date': '2019-06-05',
#  'contents.0.claim.32.claim_line.0.line_number': 1,
#  'contents.0.claim.32.claim_line.0.from_date': '2019-06-05',
#  'contents.0.claim.32.claim_line.0.thru_date': '2019-06-05',
#  'contents.0.claim.32.claim_line.0.ndc_code': '69238183801',
#  'contents.0.claim.32.claim_line.0.quantity': 90,
#  'contents.0.claim.32.claim_line.0.allowed_amount': 30.19,
#  'contents.0.claim.33.claim_id': 'clm_0134',
#  'contents.0.claim.33.claim_type': 'R',
#  'contents.0.claim.33.admission_date': '2019-02-13',
#  'contents.0.claim.33.discharge_date': '2019-02-13',
#  'contents.0.claim.33.claim_line.0.line_number': 1,
#  'contents.0.claim.33.claim_line.0.from_date': '2019-02-13',
#  'contents.0.claim.33.claim_line.0.thru_date': '2019-02-13',
#  'contents.0.claim.33.claim_line.0.ndc_code': '00591271701',
#  'contents.0.claim.33.claim_line.0.quantity': 30,
#  'contents.0.claim.33.claim_line.0.allowed_amount': 216.76,
#  'contents.0.claim.34.claim_id': 'clm_0135',
#  'contents.0.claim.34.claim_type': 'P',
#  'contents.0.claim.34.admission_date': '2018-06-01',
#  'contents.0.claim.34.discharge_date': '2018-06-01',
#  'contents.0.claim.34.taxonomy_code': '207R00000X',
#  'contents.0.claim.34.place_of_service': 11,
#  'contents.0.claim.34.principle_diagnosis': 'I889',
#  'contents.0.claim.34.diagnosis_codes.0': 'I889',
#  'contents.0.claim.34.claim_line.0.line_number': 1,
#  'contents.0.claim.34.claim_line.0.from_date': '2018-06-01',
#  'contents.0.claim.34.claim_line.0.thru_date': '2018-06-01',
#  'contents.0.claim.34.claim_line.0.procedure_code': '99213',
#  'contents.0.claim.34.claim_line.0.quantity': 1,
#  'contents.0.claim.34.claim_line.0.allowed_amount': 156.78,
#  'contents.0.claim.35.claim_id': 'clm_0136',
#  'contents.0.claim.35.claim_type': 'P',
#  'contents.0.claim.35.admission_date': '2019-06-14',
#  'contents.0.claim.35.discharge_date': '2019-06-14',
#  'contents.0.claim.35.taxonomy_code': '363A00000X',
#  'contents.0.claim.35.place_of_service': 11,
#  'contents.0.claim.35.principle_diagnosis': 'F909',
#  'contents.0.claim.35.diagnosis_codes.0': 'F909',
#  'contents.0.claim.35.claim_line.0.line_number': 1,
#  'contents.0.claim.35.claim_line.0.from_date': '2019-06-14',
#  'contents.0.claim.35.claim_line.0.thru_date': '2019-06-14',
#  'contents.0.claim.35.claim_line.0.procedure_code': '99214',
#  'contents.0.claim.35.claim_line.0.quantity': 1,
#  'contents.0.claim.35.claim_line.0.allowed_amount': 129.2,
#  'contents.0.claim.35.claim_line.1.line_number': 2,
#  'contents.0.claim.35.claim_line.1.from_date': '2019-06-14',
#  'contents.0.claim.35.claim_line.1.thru_date': '2019-06-14',
#  'contents.0.claim.35.claim_line.1.procedure_code': '96127',
#  'contents.0.claim.35.claim_line.1.quantity': 2,
#  'contents.0.claim.35.claim_line.1.allowed_amount': 15.3,
#  'contents.0.claim.36.claim_id': 'clm_0137',
#  'contents.0.claim.36.claim_type': 'R',
#  'contents.0.claim.36.admission_date': '2019-05-08',
#  'contents.0.claim.36.discharge_date': '2019-05-08',
#  'contents.0.claim.36.claim_line.0.line_number': 1,
#  'contents.0.claim.36.claim_line.0.from_date': '2019-05-08',
#  'contents.0.claim.36.claim_line.0.thru_date': '2019-05-08',
#  'contents.0.claim.36.claim_line.0.ndc_code': '16571020150',
#  'contents.0.claim.36.claim_line.0.quantity': 20,
#  'contents.0.claim.36.claim_line.0.allowed_amount': 3.31,
#  'contents.0.claim.37.claim_id': 'clm_0138',
#  'contents.0.claim.37.claim_type': 'P',
#  'contents.0.claim.37.admission_date': '2019-04-16',
#  'contents.0.claim.37.discharge_date': '2019-04-16',
#  'contents.0.claim.37.taxonomy_code': '101YM0800X',
#  'contents.0.claim.37.place_of_service': 11,
#  'contents.0.claim.37.principle_diagnosis': 'F909',
#  'contents.0.claim.37.diagnosis_codes.0': 'F909',
#  'contents.0.claim.37.claim_line.0.line_number': 1,
#  'contents.0.claim.37.claim_line.0.from_date': '2019-04-16',
#  'contents.0.claim.37.claim_line.0.thru_date': '2019-04-16',
#  'contents.0.claim.37.claim_line.0.procedure_code': '90837',
#  'contents.0.claim.37.claim_line.0.quantity': 1,
#  'contents.0.claim.37.claim_line.0.allowed_amount': 91.15,
#  'contents.0.claim.37.claim_line.1.line_number': 2,
#  'contents.0.claim.37.claim_line.1.from_date': '2019-04-16',
#  'contents.0.claim.37.claim_line.1.thru_date': '2019-04-16',
#  'contents.0.claim.37.claim_line.1.procedure_code': '96127',
#  'contents.0.claim.37.claim_line.1.quantity': 2,
#  'contents.0.claim.37.claim_line.1.allowed_amount': 0,
#  'contents.0.claim.38.claim_id': 'clm_0139',
#  'contents.0.claim.38.claim_type': 'P',
#  'contents.0.claim.38.admission_date': '2019-05-29',
#  'contents.0.claim.38.discharge_date': '2019-05-29',
#  'contents.0.claim.38.taxonomy_code': '101YM0800X',
#  'contents.0.claim.38.place_of_service': 11,
#  'contents.0.claim.38.principle_diagnosis': 'F909',
#  'contents.0.claim.38.diagnosis_codes.0': 'F909',
#  'contents.0.claim.38.claim_line.0.line_number': 1,
#  'contents.0.claim.38.claim_line.0.from_date': '2019-05-29',
#  'contents.0.claim.38.claim_line.0.thru_date': '2019-05-29',
#  'contents.0.claim.38.claim_line.0.procedure_code': '90837',
#  'contents.0.claim.38.claim_line.0.quantity': 1,
#  'contents.0.claim.38.claim_line.0.allowed_amount': 91.15,
#  'contents.0.claim.38.claim_line.1.line_number': 2,
#  'contents.0.claim.38.claim_line.1.from_date': '2019-05-29',
#  'contents.0.claim.38.claim_line.1.thru_date': '2019-05-29',
#  'contents.0.claim.38.claim_line.1.procedure_code': '96127',
#  'contents.0.claim.38.claim_line.1.quantity': 2,
#  'contents.0.claim.38.claim_line.1.allowed_amount': 0,
#  'contents.0.claim.39.claim_id': 'clm_0140',
#  'contents.0.claim.39.claim_type': 'R',
#  'contents.0.claim.39.admission_date': '2018-09-28',
#  'contents.0.claim.39.discharge_date': '2018-09-28',
#  'contents.0.claim.39.claim_line.0.line_number': 1,
#  'contents.0.claim.39.claim_line.0.from_date': '2018-09-28',
#  'contents.0.claim.39.claim_line.0.thru_date': '2018-09-28',
#  'contents.0.claim.39.claim_line.0.ndc_code': '65862001205',
#  'contents.0.claim.39.claim_line.0.quantity': 90,
#  'contents.0.claim.39.claim_line.0.allowed_amount': 6.96,
#  'contents.0.claim.40.claim_id': 'clm_0141',
#  'contents.0.claim.40.claim_type': 'P',
#  'contents.0.claim.40.admission_date': '2019-02-15',
#  'contents.0.claim.40.discharge_date': '2019-02-15',
#  'contents.0.claim.40.taxonomy_code': '101YM0800X',
#  'contents.0.claim.40.place_of_service': 11,
#  'contents.0.claim.40.principle_diagnosis': 'F909',
#  'contents.0.claim.40.diagnosis_codes.0': 'F909',
#  'contents.0.claim.40.claim_line.0.line_number': 1,
#  'contents.0.claim.40.claim_line.0.from_date': '2019-02-15',
#  'contents.0.claim.40.claim_line.0.thru_date': '2019-02-15',
#  'contents.0.claim.40.claim_line.0.procedure_code': '90791',
#  'contents.0.claim.40.claim_line.0.quantity': 1,
#  'contents.0.claim.40.claim_line.0.allowed_amount': 119.39,
#  'contents.0.claim.40.claim_line.1.line_number': 1,
#  'contents.0.claim.40.claim_line.1.from_date': '2019-06-10',
#  'contents.0.claim.40.claim_line.1.thru_date': '2019-06-10',
#  'contents.0.claim.40.claim_line.1.procedure_code': '73030',
#  'contents.0.claim.40.claim_line.1.quantity': 1,
#  'contents.0.claim.40.claim_line.1.allowed_amount': 40.48,
#  'contents.0.claim.40.claim_line.2.line_number': 2,
#  'contents.0.claim.40.claim_line.2.from_date': '2019-02-15',
#  'contents.0.claim.40.claim_line.2.thru_date': '2019-02-15',
#  'contents.0.claim.40.claim_line.2.procedure_code': '96127',
#  'contents.0.claim.40.claim_line.2.quantity': 2,
#  'contents.0.claim.40.claim_line.2.allowed_amount': 0,
#  'contents.0.claim.41.claim_id': 'clm_0142',
#  'contents.0.claim.41.claim_type': 'R',
#  'contents.0.claim.41.admission_date': '2019-03-04',
#  'contents.0.claim.41.discharge_date': '2019-03-04',
#  'contents.0.claim.41.claim_line.0.line_number': 1,
#  'contents.0.claim.41.claim_line.0.from_date': '2019-03-04',
#  'contents.0.claim.41.claim_line.0.thru_date': '2019-03-04',
#  'contents.0.claim.41.claim_line.0.ndc_code': '65862001205',
#  'contents.0.claim.41.claim_line.0.quantity': 90,
#  'contents.0.claim.41.claim_line.0.allowed_amount': 7.18,
#  'contents.0.claim.42.claim_id': 'clm_0143',
#  'contents.0.claim.42.claim_type': 'P',
#  'contents.0.claim.42.admission_date': '2018-02-06',
#  'contents.0.claim.42.discharge_date': '2018-02-06',
#  'contents.0.claim.42.taxonomy_code': '207R00000X',
#  'contents.0.claim.42.place_of_service': 11,
#  'contents.0.claim.42.principle_diagnosis': 'E6601',
#  'contents.0.claim.42.diagnosis_codes.0': 'E6601',
#  'contents.0.claim.42.diagnosis_codes.1': 'E039',
#  'contents.0.claim.42.claim_line.0.line_number': 1,
#  'contents.0.claim.42.claim_line.0.from_date': '2018-02-06',
#  'contents.0.claim.42.claim_line.0.thru_date': '2018-02-06',
#  'contents.0.claim.42.claim_line.0.procedure_code': '83036',
#  'contents.0.claim.42.claim_line.0.quantity': 1,
#  'contents.0.claim.42.claim_line.0.allowed_amount': 14.27,
#  'contents.0.claim.42.claim_line.1.line_number': 2,
#  'contents.0.claim.42.claim_line.1.from_date': '2018-02-06',
#  'contents.0.claim.42.claim_line.1.thru_date': '2018-02-06',
#  'contents.0.claim.42.claim_line.1.procedure_code': '84443',
#  'contents.0.claim.42.claim_line.1.quantity': 1,
#  'contents.0.claim.42.claim_line.1.allowed_amount': 24.69,
#  'contents.0.claim.42.claim_line.2.line_number': 3,
#  'contents.0.claim.42.claim_line.2.from_date': '2018-02-06',
#  'contents.0.claim.42.claim_line.2.thru_date': '2018-02-06',
#  'contents.0.claim.42.claim_line.2.procedure_code': '36415',
#  'contents.0.claim.42.claim_line.2.quantity': 1,
#  'contents.0.claim.42.claim_line.2.allowed_amount': 3.57,
#  'contents.0.claim.43.claim_id': 'clm_0144',
#  'contents.0.claim.43.claim_type': 'P',
#  'contents.0.claim.43.admission_date': '2018-12-08',
#  'contents.0.claim.43.discharge_date': '2018-12-08',
#  'contents.0.claim.43.taxonomy_code': '363A00000X',
#  'contents.0.claim.43.place_of_service': 11,
#  'contents.0.claim.43.principle_diagnosis': 'F909',
#  'contents.0.claim.43.diagnosis_codes.0': 'F909',
#  'contents.0.claim.43.claim_line.0.line_number': 1,
#  'contents.0.claim.43.claim_line.0.from_date': '2018-12-08',
#  'contents.0.claim.43.claim_line.0.thru_date': '2018-12-08',
#  'contents.0.claim.43.claim_line.0.procedure_code': '99214',
#  'contents.0.claim.43.claim_line.0.quantity': 1,
#  'contents.0.claim.43.claim_line.0.allowed_amount': 128.78,
#  'contents.0.claim.43.claim_line.1.line_number': 2,
#  'contents.0.claim.43.claim_line.1.from_date': '2018-12-08',
#  'contents.0.claim.43.claim_line.1.thru_date': '2018-12-08',
#  'contents.0.claim.43.claim_line.1.procedure_code': '96127',
#  'contents.0.claim.43.claim_line.1.quantity': 2,
#  'contents.0.claim.43.claim_line.1.allowed_amount': 12.76,
#  'contents.0.claim.44.claim_id': 'clm_0145',
#  'contents.0.claim.44.claim_type': 'P',
#  'contents.0.claim.44.admission_date': '2019-04-09',
#  'contents.0.claim.44.discharge_date': '2019-04-09',
#  'contents.0.claim.44.taxonomy_code': '101YM0800X',
#  'contents.0.claim.44.place_of_service': 11,
#  'contents.0.claim.44.principle_diagnosis': 'F909',
#  'contents.0.claim.44.diagnosis_codes.0': 'F909',
#  'contents.0.claim.44.claim_line.0.line_number': 1,
#  'contents.0.claim.44.claim_line.0.from_date': '2019-04-09',
#  'contents.0.claim.44.claim_line.0.thru_date': '2019-04-09',
#  'contents.0.claim.44.claim_line.0.procedure_code': '90837',
#  'contents.0.claim.44.claim_line.0.quantity': 1,
#  'contents.0.claim.44.claim_line.0.allowed_amount': 91.15,
#  'contents.0.claim.44.claim_line.1.line_number': 2,
#  'contents.0.claim.44.claim_line.1.from_date': '2019-04-09',
#  'contents.0.claim.44.claim_line.1.thru_date': '2019-04-09',
#  'contents.0.claim.44.claim_line.1.procedure_code': '96127',
#  'contents.0.claim.44.claim_line.1.quantity': 2,
#  'contents.0.claim.44.claim_line.1.allowed_amount': 0,
#  'contents.0.claim.45.claim_id': 'clm_0146',
#  'contents.0.claim.45.claim_type': 'P',
#  'contents.0.claim.45.admission_date': '2018-02-06',
#  'contents.0.claim.45.discharge_date': '2018-02-06',
#  'contents.0.claim.45.taxonomy_code': '207R00000X',
#  'contents.0.claim.45.place_of_service': 11,
#  'contents.0.claim.45.principle_diagnosis': 'Z0000',
#  'contents.0.claim.45.diagnosis_codes.0': 'Z0000',
#  'contents.0.claim.45.diagnosis_codes.1': 'K219',
#  'contents.0.claim.45.diagnosis_codes.2': 'E039',
#  'contents.0.claim.45.diagnosis_codes.3': 'E6601',
#  'contents.0.claim.45.claim_line.0.line_number': 1,
#  'contents.0.claim.45.claim_line.0.from_date': '2018-02-06',
#  'contents.0.claim.45.claim_line.0.thru_date': '2018-02-06',
#  'contents.0.claim.45.claim_line.0.procedure_code': '99386',
#  'contents.0.claim.45.claim_line.0.quantity': 1,
#  'contents.0.claim.45.claim_line.0.allowed_amount': 328.1,
#  'contents.0.claim.46.claim_id': 'clm_0147',
#  'contents.0.claim.46.claim_type': 'P',
#  'contents.0.claim.46.admission_date': '2018-11-20',
#  'contents.0.claim.46.discharge_date': '2018-11-20',
#  'contents.0.claim.46.taxonomy_code': '225100000X',
#  'contents.0.claim.46.place_of_service': 11,
#  'contents.0.claim.46.principle_diagnosis': 'M79645',
#  'contents.0.claim.46.diagnosis_codes.0': 'M79645',
#  'contents.0.claim.46.diagnosis_codes.1': 'M25532',
#  'contents.0.claim.46.claim_line.0.line_number': 1,
#  'contents.0.claim.46.claim_line.0.from_date': '2018-11-20',
#  'contents.0.claim.46.claim_line.0.thru_date': '2018-11-20',
#  'contents.0.claim.46.claim_line.0.procedure_code': '97162',
#  'contents.0.claim.46.claim_line.0.quantity': 1,
#  'contents.0.claim.46.claim_line.0.allowed_amount': 78.66,
#  'contents.0.claim.46.claim_line.1.line_number': 2,
#  'contents.0.claim.46.claim_line.1.from_date': '2018-11-20',
#  'contents.0.claim.46.claim_line.1.thru_date': '2018-11-20',
#  'contents.0.claim.46.claim_line.1.procedure_code': '97530',
#  'contents.0.claim.46.claim_line.1.quantity': 1,
#  'contents.0.claim.46.claim_line.1.allowed_amount': 33.81,
#  'contents.0.claim.46.claim_line.2.line_number': 3,
#  'contents.0.claim.46.claim_line.2.from_date': '2018-11-20',
#  'contents.0.claim.46.claim_line.2.thru_date': '2018-11-20',
#  'contents.0.claim.46.claim_line.2.procedure_code': '97760',
#  'contents.0.claim.46.claim_line.2.quantity': 1,
#  'contents.0.claim.46.claim_line.2.allowed_amount': 36.92,
#  'contents.0.claim.47.claim_id': 'clm_0148',
#  'contents.0.claim.47.claim_type': 'R',
#  'contents.0.claim.47.admission_date': '2019-06-17',
#  'contents.0.claim.47.discharge_date': '2019-06-17',
#  'contents.0.claim.47.claim_line.0.line_number': 1,
#  'contents.0.claim.47.claim_line.0.from_date': '2019-06-17',
#  'contents.0.claim.47.claim_line.0.thru_date': '2019-06-17',
#  'contents.0.claim.47.claim_line.0.ndc_code': '68462013281',
#  'contents.0.claim.47.claim_line.0.quantity': 63,
#  'contents.0.claim.47.claim_line.0.allowed_amount': 49.28,
#  'contents.0.claim.48.claim_id': 'clm_0149',
#  'contents.0.claim.48.claim_type': 'P',
#  'contents.0.claim.48.admission_date': '2019-04-02',
#  'contents.0.claim.48.discharge_date': '2019-04-02',
#  'contents.0.claim.48.taxonomy_code': '101YM0800X',
#  'contents.0.claim.48.place_of_service': 11,
#  'contents.0.claim.48.principle_diagnosis': 'F909',
#  'contents.0.claim.48.diagnosis_codes.0': 'F909',
#  'contents.0.claim.48.claim_line.0.line_number': 1,
#  'contents.0.claim.48.claim_line.0.from_date': '2019-04-02',
#  'contents.0.claim.48.claim_line.0.thru_date': '2019-04-02',
#  'contents.0.claim.48.claim_line.0.procedure_code': '90837',
#  'contents.0.claim.48.claim_line.0.quantity': 1,
#  'contents.0.claim.48.claim_line.0.allowed_amount': 91.15,
#  'contents.0.claim.48.claim_line.1.line_number': 2,
#  'contents.0.claim.48.claim_line.1.from_date': '2019-04-02',
#  'contents.0.claim.48.claim_line.1.thru_date': '2019-04-02',
#  'contents.0.claim.48.claim_line.1.procedure_code': '96127',
#  'contents.0.claim.48.claim_line.1.quantity': 2,
#  'contents.0.claim.48.claim_line.1.allowed_amount': 0,
#  'contents.0.claim.49.claim_id': 'clm_0150',
#  'contents.0.claim.49.claim_type': 'P',
#  'contents.0.claim.49.admission_date': '2019-05-04',
#  'contents.0.claim.49.discharge_date': '2019-05-04',
#  'contents.0.claim.49.taxonomy_code': '363A00000X',
#  'contents.0.claim.49.place_of_service': 11,
#  'contents.0.claim.49.principle_diagnosis': 'F909',
#  'contents.0.claim.49.diagnosis_codes.0': 'F909',
#  'contents.0.claim.49.claim_line.0.line_number': 1,
#  'contents.0.claim.49.claim_line.0.from_date': '2019-05-04',
#  'contents.0.claim.49.claim_line.0.thru_date': '2019-05-04',
#  'contents.0.claim.49.claim_line.0.procedure_code': '99214',
#  'contents.0.claim.49.claim_line.0.quantity': 1,
#  'contents.0.claim.49.claim_line.0.allowed_amount': 129.2,
#  'contents.0.claim.49.claim_line.1.line_number': 2,
#  'contents.0.claim.49.claim_line.1.from_date': '2019-05-04',
#  'contents.0.claim.49.claim_line.1.thru_date': '2019-05-04',
#  'contents.0.claim.49.claim_line.1.procedure_code': '96127',
#  'contents.0.claim.49.claim_line.1.quantity': 2,
#  'contents.0.claim.49.claim_line.1.allowed_amount': 15.3,
#  'contents.0.claim.50.claim_id': 'clm_0151',
#  'contents.0.claim.50.claim_type': 'P',
#  'contents.0.claim.50.admission_date': '2019-06-03',
#  'contents.0.claim.50.discharge_date': '2019-06-03',
#  'contents.0.claim.50.taxonomy_code': '207RR0500X',
#  'contents.0.claim.50.place_of_service': 11,
#  'contents.0.claim.50.principle_diagnosis': 'M25551',
#  'contents.0.claim.50.diagnosis_codes.0': 'M25551',
#  'contents.0.claim.50.claim_line.0.line_number': 1,
#  'contents.0.claim.50.claim_line.0.from_date': '2019-06-03',
#  'contents.0.claim.50.claim_line.0.thru_date': '2019-06-03',
#  'contents.0.claim.50.claim_line.0.procedure_code': '77080',
#  'contents.0.claim.50.claim_line.0.quantity': 1,
#  'contents.0.claim.50.claim_line.0.allowed_amount': 92.16,
#  'contents.0.claim.51.claim_id': 'clm_0152',
#  'contents.0.claim.51.claim_type': 'P',
#  'contents.0.claim.51.admission_date': '2019-06-03',
#  'contents.0.claim.51.discharge_date': '2019-06-03',
#  'contents.0.claim.51.taxonomy_code': '2085R0202X',
#  'contents.0.claim.51.place_of_service': 11,
#  'contents.0.claim.51.principle_diagnosis': 'Z1231',
#  'contents.0.claim.51.diagnosis_codes.0': 'Z1231',
#  'contents.0.claim.51.claim_line.0.line_number': 1,
#  'contents.0.claim.51.claim_line.0.from_date': '2019-06-03',
#  'contents.0.claim.51.claim_line.0.thru_date': '2019-06-03',
#  'contents.0.claim.51.claim_line.0.procedure_code': '77067',
#  'contents.0.claim.51.claim_line.0.quantity': 1,
#  'contents.0.claim.51.claim_line.0.allowed_amount': 305.88,
#  'contents.0.claim.51.claim_line.1.line_number': 2,
#  'contents.0.claim.51.claim_line.1.from_date': '2019-06-03',
#  'contents.0.claim.51.claim_line.1.thru_date': '2019-06-03',
#  'contents.0.claim.51.claim_line.1.procedure_code': '77063',
#  'contents.0.claim.51.claim_line.1.quantity': 1,
#  'contents.0.claim.51.claim_line.1.allowed_amount': 123.94,
#  'contents.0.claim.52.claim_id': 'clm_0153',
#  'contents.0.claim.52.claim_type': 'R',
#  'contents.0.claim.52.admission_date': '2018-12-23',
#  'contents.0.claim.52.discharge_date': '2018-12-23',
#  'contents.0.claim.52.claim_line.0.line_number': 1,
#  'contents.0.claim.52.claim_line.0.from_date': '2018-12-23',
#  'contents.0.claim.52.claim_line.0.thru_date': '2018-12-23',
#  'contents.0.claim.52.claim_line.0.ndc_code': '00527134901',
#  'contents.0.claim.52.claim_line.0.quantity': 90,
#  'contents.0.claim.52.claim_line.0.allowed_amount': 42.71,
#  'contents.0.claim.53.claim_id': 'clm_0154',
#  'contents.0.claim.53.claim_type': 'R',
#  'contents.0.claim.53.admission_date': '2019-03-12',
#  'contents.0.claim.53.discharge_date': '2019-03-12',
#  'contents.0.claim.53.claim_line.0.line_number': 1,
#  'contents.0.claim.53.claim_line.0.from_date': '2019-03-12',
#  'contents.0.claim.53.claim_line.0.thru_date': '2019-03-12',
#  'contents.0.claim.53.claim_line.0.ndc_code': '00591271701',
#  'contents.0.claim.53.claim_line.0.quantity': 30,
#  'contents.0.claim.53.claim_line.0.allowed_amount': 216.76,
#  'contents.0.claim.54.claim_id': 'clm_0155',
#  'contents.0.claim.54.claim_type': 'R',
#  'contents.0.claim.54.admission_date': '2018-11-30',
#  'contents.0.claim.54.discharge_date': '2018-11-30',
#  'contents.0.claim.54.claim_line.0.line_number': 1,
#  'contents.0.claim.54.claim_line.0.from_date': '2018-11-30',
#  'contents.0.claim.54.claim_line.0.thru_date': '2018-11-30',
#  'contents.0.claim.54.claim_line.0.ndc_code': '10702010001',
#  'contents.0.claim.54.claim_line.0.quantity': 35,
#  'contents.0.claim.54.claim_line.0.allowed_amount': 12.61,
#  'contents.0.claim.55.claim_id': 'clm_0156',
#  'contents.0.claim.55.claim_type': 'P',
#  'contents.0.claim.55.admission_date': '2019-05-07',
#  'contents.0.claim.55.discharge_date': '2019-05-07',
#  'contents.0.claim.55.taxonomy_code': '101YM0800X',
#  'contents.0.claim.55.place_of_service': 11,
#  'contents.0.claim.55.principle_diagnosis': 'F909',
#  'contents.0.claim.55.diagnosis_codes.0': 'F909',
#  'contents.0.claim.55.claim_line.0.line_number': 1,
#  'contents.0.claim.55.claim_line.0.from_date': '2019-05-07',
#  'contents.0.claim.55.claim_line.0.thru_date': '2019-05-07',
#  'contents.0.claim.55.claim_line.0.procedure_code': '90837',
#  'contents.0.claim.55.claim_line.0.quantity': 1,
#  'contents.0.claim.55.claim_line.0.allowed_amount': 91.15,
#  'contents.0.claim.55.claim_line.1.line_number': 2,
#  'contents.0.claim.55.claim_line.1.from_date': '2019-05-07',
#  'contents.0.claim.55.claim_line.1.thru_date': '2019-05-07',
#  'contents.0.claim.55.claim_line.1.procedure_code': '96127',
#  'contents.0.claim.55.claim_line.1.quantity': 2,
#  'contents.0.claim.55.claim_line.1.allowed_amount': 0,
#  'contents.0.claim.56.claim_id': 'clm_0157',
#  'contents.0.claim.56.claim_type': 'P',
#  'contents.0.claim.56.admission_date': '2018-09-24',
#  'contents.0.claim.56.discharge_date': '2018-09-24',
#  'contents.0.claim.56.taxonomy_code': '207R00000X',
#  'contents.0.claim.56.place_of_service': 11,
#  'contents.0.claim.56.principle_diagnosis': 'Z23',
#  'contents.0.claim.56.diagnosis_codes.0': 'Z23',
#  'contents.0.claim.56.claim_line.0.line_number': 1,
#  'contents.0.claim.56.claim_line.0.from_date': '2018-09-24',
#  'contents.0.claim.56.claim_line.0.thru_date': '2018-09-24',
#  'contents.0.claim.56.claim_line.0.procedure_code': '90686',
#  'contents.0.claim.56.claim_line.0.quantity': 1,
#  'contents.0.claim.56.claim_line.0.allowed_amount': 18.03,
#  'contents.0.claim.56.claim_line.1.line_number': 2,
#  'contents.0.claim.56.claim_line.1.from_date': '2018-09-24',
#  'contents.0.claim.56.claim_line.1.thru_date': '2018-09-24',
#  'contents.0.claim.56.claim_line.1.procedure_code': '90471',
#  'contents.0.claim.56.claim_line.1.quantity': 1,
#  'contents.0.claim.56.claim_line.1.allowed_amount': 54.3,
#  'contents.0.claim.57.claim_id': 'clm_0158',
#  'contents.0.claim.57.claim_type': 'R',
#  'contents.0.claim.57.admission_date': '2018-12-23',
#  'contents.0.claim.57.discharge_date': '2018-12-23',
#  'contents.0.claim.57.claim_line.0.line_number': 1,
#  'contents.0.claim.57.claim_line.0.from_date': '2018-12-23',
#  'contents.0.claim.57.claim_line.0.thru_date': '2018-12-23',
#  'contents.0.claim.57.claim_line.0.ndc_code': '65862001205',
#  'contents.0.claim.57.claim_line.0.quantity': 90,
#  'contents.0.claim.57.claim_line.0.allowed_amount': 6.96,
#  'contents.0.claim.58.claim_id': 'clm_0159',
#  'contents.0.claim.58.claim_type': 'P',
#  'contents.0.claim.58.admission_date': '2019-02-26',
#  'contents.0.claim.58.discharge_date': '2019-02-26',
#  'contents.0.claim.58.taxonomy_code': '101YM0800X',
#  'contents.0.claim.58.place_of_service': 11,
#  'contents.0.claim.58.principle_diagnosis': 'F909',
#  'contents.0.claim.58.diagnosis_codes.0': 'F909',
#  'contents.0.claim.58.claim_line.0.line_number': 1,
#  'contents.0.claim.58.claim_line.0.from_date': '2019-02-26',
#  'contents.0.claim.58.claim_line.0.thru_date': '2019-02-26',
#  'contents.0.claim.58.claim_line.0.procedure_code': '90837',
#  'contents.0.claim.58.claim_line.0.quantity': 1,
#  'contents.0.claim.58.claim_line.0.allowed_amount': 91.15,
#  'contents.0.claim.58.claim_line.1.line_number': 2,
#  'contents.0.claim.58.claim_line.1.from_date': '2019-02-26',
#  'contents.0.claim.58.claim_line.1.thru_date': '2019-02-26',
#  'contents.0.claim.58.claim_line.1.procedure_code': '96127',
#  'contents.0.claim.58.claim_line.1.quantity': 2,
#  'contents.0.claim.58.claim_line.1.allowed_amount': 0,
#  'contents.0.claim.59.claim_id': 'clm_0160',
#  'contents.0.claim.59.claim_type': 'P',
#  'contents.0.claim.59.admission_date': '2018-12-13',
#  'contents.0.claim.59.discharge_date': '2018-12-13',
#  'contents.0.claim.59.taxonomy_code': '225100000X',
#  'contents.0.claim.59.place_of_service': 11,
#  'contents.0.claim.59.principle_diagnosis': 'M25551',
#  'contents.0.claim.59.diagnosis_codes.0': 'M25551',
#  'contents.0.claim.59.claim_line.0.line_number': 1,
#  'contents.0.claim.59.claim_line.0.from_date': '2018-12-13',
#  'contents.0.claim.59.claim_line.0.thru_date': '2018-12-13',
#  'contents.0.claim.59.claim_line.0.procedure_code': '97110',
#  'contents.0.claim.59.claim_line.0.quantity': 1,
#  'contents.0.claim.59.claim_line.0.allowed_amount': 31.4,
#  'contents.0.claim.60.claim_id': 'clm_0161',
#  'contents.0.claim.60.claim_type': 'P',
#  'contents.0.claim.60.admission_date': '2019-04-30',
#  'contents.0.claim.60.discharge_date': '2019-04-30',
#  'contents.0.claim.60.taxonomy_code': '101YM0800X',
#  'contents.0.claim.60.place_of_service': 11,
#  'contents.0.claim.60.principle_diagnosis': 'F909',
#  'contents.0.claim.60.diagnosis_codes.0': 'F909',
#  'contents.0.claim.60.claim_line.0.line_number': 1,
#  'contents.0.claim.60.claim_line.0.from_date': '2019-04-30',
#  'contents.0.claim.60.claim_line.0.thru_date': '2019-04-30',
#  'contents.0.claim.60.claim_line.0.procedure_code': '90837',
#  'contents.0.claim.60.claim_line.0.quantity': 1,
#  'contents.0.claim.60.claim_line.0.allowed_amount': 91.15,
#  'contents.0.claim.60.claim_line.1.line_number': 2,
#  'contents.0.claim.60.claim_line.1.from_date': '2019-04-30',
#  'contents.0.claim.60.claim_line.1.thru_date': '2019-04-30',
#  'contents.0.claim.60.claim_line.1.procedure_code': '96127',
#  'contents.0.claim.60.claim_line.1.quantity': 2,
#  'contents.0.claim.60.claim_line.1.allowed_amount': 0,
#  'contents.0.claim.61.claim_id': 'clm_0162',
#  'contents.0.claim.61.claim_type': 'P',
#  'contents.0.claim.61.admission_date': '2019-06-11',
#  'contents.0.claim.61.discharge_date': '2019-06-11',
#  'contents.0.claim.61.taxonomy_code': '101YM0800X',
#  'contents.0.claim.61.place_of_service': 11,
#  'contents.0.claim.61.principle_diagnosis': 'F909',
#  'contents.0.claim.61.diagnosis_codes.0': 'F909',
#  'contents.0.claim.61.claim_line.0.line_number': 1,
#  'contents.0.claim.61.claim_line.0.from_date': '2019-06-11',
#  'contents.0.claim.61.claim_line.0.thru_date': '2019-06-11',
#  'contents.0.claim.61.claim_line.0.procedure_code': '90837',
#  'contents.0.claim.61.claim_line.0.quantity': 1,
#  ...}

# %% [markdown]
# ### Declare search criteria variable

# %%
inpatient_search_criteria = {
    'claim_type': ['I'],
    'type_of_bill': [str(i).zfill(4) for i in range(110, 130)], 
    'revenue_code': [str(i).zfill(4) for i in range(100, 220)] + [str(i).zfill(4) for i in range(1000, 1010)]}

print(inpatient_search_criteria)
# Out:
# {'claim_type': ['I'], 'type_of_bill': ['0110', '0111', '0112', '0113', '0114', '0115', '0116', '0117', '0118', '0119', '0120', '0121', '0122', '0123', '0124', '0125', '0126', '0127', '0128', '0129'], 'revenue_code': ['0100', '0101', '0102', '0103', '0104', '0105', '0106', '0107', '0108', '0109', '0110', '0111', '0112', '0113', '0114', '0115', '0116', '0117', '0118', '0119', '0120', '0121', '0122', '0123', '0124', '0125', '0126', '0127', '0128', '0129', '0130', '0131', '0132', '0133', '0134', '0135', '0136', '0137', '0138', '0139', '0140', '0141', '0142', '0143', '0144', '0145', '0146', '0147', '0148', '0149', '0150', '0151', '0152', '0153', '0154', '0155', '0156', '0157', '0158', '0159', '0160', '0161', '0162', '0163', '0164', '0165', '0166', '0167', '0168', '0169', '0170', '0171', '0172', '0173', '0174', '0175', '0176', '0177', '0178', '0179', '0180', '0181', '0182', '0183', '0184', '0185', '0186', '0187', '0188', '0189', '0190', '0191', '0192', '0193', '0194', '0195', '0196', '0197', '0198', '0199', '0200', '0201', '0202', '0203', '0204', '0205', '0206', '0207', '0208', '0209', '0210', '0211', '0212', '0213', '0214', '0215', '0216', '0217', '0218', '0219', '1000', '1001', '1002', '1003', '1004', '1005', '1006', '1007', '1008', '1009']}

# %%
inpatient_results = table.find_and(inpatient_search_criteria)

inpatient_results
# Out:
# {'member': {'contents.2', 'contents.8'},
#  'claim': {'contents.2.claim.0', 'contents.8.claim.46'},
#  'claim_line': set()}

# %%
# Start with null list
_li = []

# build dictionary using for loop
_dict = {}

for key, values in inpatient_results.items():
    if key == 'member':
        for v in values:
            # Include member_id 
            _api_output['member_id'].append(table.hash_table[v + '.member_id'])


# append dictionary to list


    {'member_id', 'member_age', 'admission_date', 'discharge_date', 'principle_diagnosis'}
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/chienho/my_dev/projects/project_lambda/querying-json.ipynb Cell 9' in <cell line: 7>()
#       <a href='vscode-notebook-cell:/Users/chienho/my_dev/projects/project_lambda/querying-json.ipynb#ch0000020?line=7'>8</a>     if key == 'member':
#       <a href='vscode-notebook-cell:/Users/chienho/my_dev/projects/project_lambda/querying-json.ipynb#ch0000020?line=8'>9</a>         for v in values:
#      <a href='vscode-notebook-cell:/Users/chienho/my_dev/projects/project_lambda/querying-json.ipynb#ch0000020?line=9'>10</a>             # Include member_id
# ---> <a href='vscode-notebook-cell:/Users/chienho/my_dev/projects/project_lambda/querying-json.ipynb#ch0000020?line=10'>11</a>             _api_output['member_id'].append(table.hash_table[v + '.member_id'])
#      <a href='vscode-notebook-cell:/Users/chienho/my_dev/projects/project_lambda/querying-json.ipynb#ch0000020?line=13'>14</a> # append dictionary to list
#      <a href='vscode-notebook-cell:/Users/chienho/my_dev/projects/project_lambda/querying-json.ipynb#ch0000020?line=16'>17</a>     {'member_id', 'member_age', 'admission_date', 'discharge_date', 'principle_diagnosis'}
#
# NameError: name '_api_output' is not defined

# %%
_api_output
# Out:
# [{'admission_date',
#   'discharge_date',
#   'member_age',
#   'member_id',
#   'principle_diagnosis'}]

# %%
# initialize object to store all values from matching keys
_api_output = {
    'member_id': [],
    'member_age': [],
    'admission_date': [],
    'discharge_date': [],
    'principle_diagnosis': []
    }

for key, values in inpatient_results.items():
    if key == 'member':
        for v in values:
            # Include member_id 
            _api_output['member_id'].append(table.hash_table[v + '.member_id'])
            # Include member_age 
            _api_output['member_age'].append(table.hash_table[v + '.member_age'])
    if key == 'claim':
        for v in values:
            # Include admission_date
            _api_output['admission_date'].append(table.hash_table[v + '.admission_date'])
            # Include discharge_date
            _api_output['discharge_date'].append(table.hash_table[v + '.discharge_date'])
            # Include principle_diagnosis
            _api_output['principle_diagnosis'].append(table.hash_table[v + '.principle_diagnosis'])

# %%
_api_output
# Out:
# {'member_id': ['mbr_09', 'mbr_03'],
#  'member_age': [332, 231],
#  'admission_date': ['2019-06-23', '2018-12-31'],
#  'discharge_date': ['2019-06-27', '2019-01-02'],
#  'principle_diagnosis': ['S6722XA', 'O99284']}

# %%
# ideal: list of dictionary
[   
    {
        'member_id': 'mbr_03',
        'member_age': 231
    },
    {
        'member_id': 'mbr_09',
        'member_age': 332
    }
]
# Out:
# [{'member_id': 'mbr_03', 'member_age': 231},
#  {'member_id': 'mbr_09', 'member_age': 332}]
